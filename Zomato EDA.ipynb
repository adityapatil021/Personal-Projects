# %%
import pandas as pd 
import numpy as np 
import seaborn as sns

# %%
df=pd.read_csv("zomato.csv")

# %%
df
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %%
df.count()
# Out:
# url                            51717
# address                        51717
# name                           51717
# online_order                   51717
# book_table                     51717
# rate                           43942
# votes                          51717
# phone                          50509
# location                       51696
# rest_type                      51490
# dish_liked                     23639
# cuisines                       51672
# approx_cost(for two people)    51371
# reviews_list                   51717
# menu_item                      51717
# listed_in(type)                51717
# listed_in(city)                51717
# dtype: int64

# %%
df.dtypes
# Out:
# url                            object
# address                        object
# name                           object
# online_order                   object
# book_table                     object
# rate                           object
# votes                           int64
# phone                          object
# location                       object
# rest_type                      object
# dish_liked                     object
# cuisines                       object
# approx_cost(for two people)    object
# reviews_list                   object
# menu_item                      object
# listed_in(type)                object
# listed_in(city)                object
# dtype: object

# %%
df.menu_item.sort_values()
# Out:
# 17264    ["A Simple Man's Breakfast", "The Gentleman's ...
# 49029    ["A Simple Man's Breakfast", "The Gentleman's ...
# 4027     ["A Simple Man's Breakfast", "The Gentleman's ...
# 34544    ["A Simple Man's Breakfast", "The Gentleman's ...
# 5611     ["Baker's Basket", 'The Continental Breakfast'...
#                                ...
# 18342                                                   []
# 18343                                                   []
# 18344                                                   []
# 21250                                                   []
# 51716                                                   []
# Name: menu_item, Length: 51717, dtype: object

# %%
df.menu_item.nunique()
# Out:
# 9098

# %%
pd.unique(df['menu_item'])
# Out:
# array(['[]',
# ...

# %%
df.shape
# Out:
# (51717, 17)

# %%
df.isnull().mean()
# Out:
# url                            0.000000
# address                        0.000000
# name                           0.000000
# online_order                   0.000000
# book_table                     0.000000
# rate                           0.150337
# votes                          0.000000
# phone                          0.023358
# location                       0.000406
# rest_type                      0.004389
# dish_liked                     0.542916
# cuisines                       0.000870
# approx_cost(for two people)    0.006690
# reviews_list                   0.000000
# menu_item                      0.000000
# listed_in(type)                0.000000
# listed_in(city)                0.000000
# dtype: float64

# %%
df.isnull().sum()
# Out:
# url                                0
# address                            0
# name                               0
# online_order                       0
# book_table                         0
# rate                            7775
# votes                              0
# phone                           1208
# location                          21
# rest_type                        227
# dish_liked                     28078
# cuisines                          45
# approx_cost(for two people)      346
# reviews_list                       0
# menu_item                          0
# listed_in(type)                    0
# listed_in(city)                    0
# dtype: int64

# %%
df.nunique()
# Out:
# url                            51717
# address                        11495
# name                            8792
# online_order                       2
# book_table                         2
# rate                              64
# votes                           2328
# phone                          14926
# location                          93
# rest_type                         93
# dish_liked                      5271
# cuisines                        2723
# approx_cost(for two people)       70
# reviews_list                   22513
# menu_item                       9098
# listed_in(type)                    7
# listed_in(city)                   30
# dtype: int64

# %% [markdown]
# ### point to be noted
# the url data is around 51k and address  11k and around 8 names

# %%
df.address.value_counts()
# Out:
# Delivery Only                                                                              128
# 14th Main, 4th Sector, HSR, Bangalore                                                       71
# The Ritz-Carlton, 99, Residency Road, Bangalore                                             61
# Citrus Hotels, 34, Cunningham Road, Bangalore                                               53
# Conrad Bengaluru, Kensington Road, Ulsoor, Bangalore                                        49
#                                                                                           ...
# Behind Vijaya Sree Hospital, Gottigere, Bannerghatta Road, Bangalore                         1
# 6, Sri Jayappa Reddy Complex, Near Infosys, Gate 6, Phase 1, Electronic City, Bangalore      1
# 1197/1, 22nd A Cross, Sector 3, HSR Club Road, HSR, Bangalore                                1
# Near BHEL, Mysore Road, Bangalore                                                            1
# ...

# %%
#check if the multiple urls for a single address belong to a single restaurant
df.query('address == "14th Main, 4th Sector, HSR, Bangalore"')['name'].unique()
# Out:
# array(['Swathi Restaurant', 'Fujian Express', 'Nagas', 'Kababji Cafe',
#        'Hottey Smokey', 'The Duke of Juices', 'Easy Bites',
#        'Empire Restaurant', 'Punjabites', 'Karama Restaurant',
#        'Dabba Gosht', 'Kitchens@HSR', 'Shaadi Ki Biryani',
#        'Chef Delicacies', 'Rara Avis', 'Arzak', 'Vegetarea',
#        'SGS Non Veg - Gundu Pulav', 'Beijing Bites', 'Bottle Genie'],
#       dtype=object)

# %% [markdown]
# So it does prove that one address can be linked to multiple resturants as it can be a food hub or a mall where multiple food stalls or restaurants are located

# %%
df.query('address == "The Ritz-Carlton, 99, Residency Road, Bangalore"')['name'].unique()
# Out:
# array(['The Market - The Ritz-Carlton', 'Ganache - The Ritz-Carlton',
#        'Bang - The Ritz-Carlton', 'Riwaz - The Ritz-Carlton',
#        'The Lantern Restaurant & Bar - The Ritz-Carlton...',
#        'The Lobby Lounge - The Ritz-Carlton',
#        'The Ritz-Carlton Bar - The Ritz-Carlton',
#        'Grill 99 - The Ritz-Carlton'], dtype=object)

# %% [markdown]
# Same is the thing for ritz carlton address. Verified

# %%
df[['location','address','listed_in(city)']].nunique()
# Out:
# location              93
# address            11495
# listed_in(city)       30
# dtype: int64

# %%
df.groupby(['address','location','listed_in(city)'])['rate']

# %%
zomato=df.copy()

# %%
zomato
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %%
df= df.rename(columns={'rate':'rating','approx_cost(for two people)':'cost','listed_in(city)':'city','listed_in(type)':'type'})

# %%
df
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %%
df.isnull().mean()
# Out:
# url             0.000000
# address         0.000000
# name            0.000000
# online_order    0.000000
# book_table      0.000000
# rating          0.150337
# votes           0.000000
# phone           0.023358
# location        0.000406
# rest_type       0.004389
# dish_liked      0.542916
# cuisines        0.000870
# cost            0.006690
# reviews_list    0.000000
# menu_item       0.000000
# type            0.000000
# city            0.000000
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
zomato=df.copy()

# %%
zomato
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# url                 0
# address             0
# name                0
# online_order        0
# book_table          0
# rating           7775
# votes               0
# phone            1208
# location           21
# rest_type         227
# dish_liked      28078
# cuisines           45
# cost              346
# reviews_list        0
# menu_item           0
# type                0
# city                0
# dtype: int64

# %%
df['cost']= df['cost'].astype(str)
df['cost']=df['cost'].apply(lambda x: x.replace(',',''))
df['cost']= df['cost'].astype(float)

# %%
import dtale
